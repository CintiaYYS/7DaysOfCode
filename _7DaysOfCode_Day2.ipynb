# %% [markdown]
# <a href="https://colab.research.google.com/github/CintiaYYS/7DaysOfCode/blob/main/_7DaysOfCode_Day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Projeto - #7DaysOfCode *Alura*

# %% [markdown]
# #Day - 1

# %% [markdown]
# ##Import

# %%
import pandas as pd
import numpy  as np

# %% [markdown]
# ##Carregando dados

# %%
# Lendo o arquivo parquet baixado
dados_exemplares = pd.read_parquet('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_1-Importando_dados/Datasets/dados_exemplares.parquet')

# %%
emprestimos_2010_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20101.csv?raw=true')
emprestimos_2010_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20102.csv?raw=true')
emprestimos_2011_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20111.csv?raw=true')
emprestimos_2011_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20112.csv?raw=true')
emprestimos_2012_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20121.csv?raw=true')
emprestimos_2012_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20122.csv?raw=true')
emprestimos_2013_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20131.csv?raw=true')
emprestimos_2013_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20132.csv?raw=true')
emprestimos_2014_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20141.csv?raw=true')
emprestimos_2014_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20142.csv?raw=true')
emprestimos_2015_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20151.csv?raw=true')
emprestimos_2015_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20152.csv?raw=true')
emprestimos_2016_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20161.csv?raw=true')
emprestimos_2016_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20162.csv?raw=true')
emprestimos_2017_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20171.csv?raw=true')
emprestimos_2017_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20172.csv?raw=true')
emprestimos_2018_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20181.csv?raw=true')
emprestimos_2018_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20182.csv?raw=true')
emprestimos_2019_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20191.csv?raw=true')
emprestimos_2019_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20192.csv?raw=true')
emprestimos_2020_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20201.csv?raw=true')

# %% [markdown]
# ## Entendendo os dados

# %%
emprestimos_2010_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95357 entries, 0 to 95356
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id_emprestimo         95357 non-null  int64
#  1   codigo_barras         95357 non-null  object
#  2   data_renovacao        38803 non-null  object
#  3   data_emprestimo       95357 non-null  object
#  4   data_devolucao        95354 non-null  object
#  5   matricula_ou_siape    95155 non-null  float64
#  6   tipo_vinculo_usuario  95357 non-null  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 5.1+ MB

# %%
emprestimos_2016_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118733 entries, 0 to 118732
# Data columns (total 7 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id_emprestimo         118733 non-null  int64
#  1   codigo_barras         118733 non-null  object
#  2   data_renovacao        51161 non-null   object
#  3   data_emprestimo       118733 non-null  object
#  4   data_devolucao        118706 non-null  object
#  5   matricula_ou_siape    118539 non-null  float64
#  6   tipo_vinculo_usuario  118733 non-null  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 6.3+ MB

# %%
emprestimos_2019_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83687 entries, 0 to 83686
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id_emprestimo         83687 non-null  int64
#  1   codigo_barras         83687 non-null  object
#  2   data_renovacao        35579 non-null  object
#  3   data_emprestimo       83687 non-null  object
#  4   data_devolucao        83650 non-null  object
#  5   matricula_ou_siape    83632 non-null  float64
#  6   tipo_vinculo_usuario  83687 non-null  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 4.5+ MB

# %%
dados_exemplares.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 546237 entries, 0 to 568584
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id_exemplar       546237 non-null  int64
#  1   codigo_barras     546237 non-null  object
#  2   colecao           546237 non-null  object
#  3   biblioteca        546237 non-null  object
#  4   status_material   546237 non-null  object
#  5   localizacao       546237 non-null  int64
#  6   registro_sistema  546237 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 33.3+ MB

# %% [markdown]
# ## Unindo as tabelas de empréstimos em uma só

# %%
nomes_tabelas_emprestimos = ['emprestimos_2010_1','emprestimos_2010_2','emprestimos_2011_1',
                             'emprestimos_2011_2','emprestimos_2012_1','emprestimos_2 012_2',
                             'emprestimos_2013_1','emprestimos_2013_2','emprestimos_2014_1',
                             'emprestimos_2014_2','emprestimos_2015_1','emprestimos_2015_2',
                             'emprestimos_2016_1','emprestimos_2016_2','emprestimos_2017_1',
                             'emprestimos_2017_2','emprestimos_2018_1','emprestimos_2018_2',
                             'emprestimos_2019_1','emprestimos_2019_2','emprestimos_2020_1']

# %%
emprestimos_biblioteca = pd.concat([emprestimos_2010_1,emprestimos_2010_2,emprestimos_2011_1,
                                    emprestimos_2011_2,emprestimos_2012_1,emprestimos_2012_2,
                                    emprestimos_2013_1,emprestimos_2014_1,emprestimos_2014_2,
                                    emprestimos_2015_1,emprestimos_2015_2,emprestimos_2016_1,
                                    emprestimos_2017_1,emprestimos_2017_2,emprestimos_2018_1,
                                    emprestimos_2018_2,emprestimos_2019_1,emprestimos_2019_2,
                                    emprestimos_2020_1], ignore_index=True)

# %%
len(emprestimos_biblioteca)
# Out:
# 2026643

# %% [markdown]
# ## Removendo registros duplicados

# %%
emprestimos_biblioteca = emprestimos_biblioteca.drop_duplicates()

# %%
len(emprestimos_biblioteca)
# Out:
# 2026606

# %%
emprestimos_biblioteca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2026606 entries, 0 to 2026642
# Data columns (total 7 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id_emprestimo         int64
#  1   codigo_barras         object
#  2   data_renovacao        object
#  3   data_emprestimo       object
#  4   data_devolucao        object
#  5   matricula_ou_siape    float64
#  6   tipo_vinculo_usuario  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 123.7+ MB

# %%
emprestimos_biblioteca.head(5)
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         709685       L167050                            NaN
# 2         709686    2006017618  2010/01/26 08:07:01.738000000
# 3         709687       L184117  2010/01/18 11:07:46.470000000
# 8         709688    2007027500  2010/01/19 15:59:26.464000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 3  2010/01/04 08:24:21.284000000  2010/02/03 08:58:45.692000000
# 8  2010/01/04 08:27:33.569000000  2010/02/03 13:06:30.662000000
#
#    matricula_ou_siape    tipo_vinculo_usuario
# 0        2.008023e+09      ALUNO DE GRADUAÇÃO
# 1        2.008023e+09      ALUNO DE GRADUAÇÃO
# 2        2.008112e+09  ALUNO DE PÓS-GRADUAÇÃO
# ...

# %% [markdown]
# ##Mesclando as duas tabelas em uma só

# %%
df_dados = emprestimos_biblioteca.merge(dados_exemplares, how='left', on='codigo_barras')

# %%
df_dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2030010 entries, 0 to 2030009
# Data columns (total 13 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id_emprestimo         int64
#  1   codigo_barras         object
#  2   data_renovacao        object
#  3   data_emprestimo       object
#  4   data_devolucao        object
#  5   matricula_ou_siape    float64
#  6   tipo_vinculo_usuario  object
#  7   id_exemplar           float64
#  8   colecao               object
#  9   biblioteca            object
#  10  status_material       object
#  11  localizacao           float64
#  12  registro_sistema      float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 201.3+ MB

# %%
df_dados.head(5)
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         709685       L167050                            NaN
# 2         709686    2006017618  2010/01/26 08:07:01.738000000
# 3         709687       L184117  2010/01/18 11:07:46.470000000
# 4         709688    2007027500  2010/01/19 15:59:26.464000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 3  2010/01/04 08:24:21.284000000  2010/02/03 08:58:45.692000000
# 4  2010/01/04 08:27:33.569000000  2010/02/03 13:06:30.662000000
#
#    matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0        2.008023e+09      ALUNO DE GRADUAÇÃO      13259.0  Acervo Circulante
# ...

# %% [markdown]
# ##Verificando linhas com elementos NaN

# %%
linhas_NaN = df_dados[df_dados.isnull().any(axis=1)]
linhas_NaN
# Out:
#          id_emprestimo codigo_barras data_renovacao  \
# 0               709684       L095049            NaN
# 1               709685       L167050            NaN
# 6               709690    2007019312            NaN
# 8               709692       L187962            NaN
# 9               709693       L192776            NaN
# ...                ...           ...            ...
# 2030005        2989086    2008047044            NaN
# 2030006        2989087    2008047047            NaN
# 2030007        2989088    2010052905            NaN
# 2030008        2989089    2010048023            NaN
# 2030009        2989090    2013106838            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1        2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 6        2010/01/04 08:49:57.857000000  2010/01/13 09:58:25.443000000
# ...

# %%
linhas_NaN_menos_Renovacao = df_dados[df_dados.drop(columns=['data_renovacao']).isna().any(axis=1)]
linhas_NaN_menos_Renovacao
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 17              709701       L163841  2010/01/19 19:02:53.450000000
# 98              709782       L165850                            NaN
# 109             709793       L178388  2010/01/19 16:31:44.491000000
# 118             709802    2009032201  2010/01/19 16:13:22.082000000
# 119             709803       L188583  2010/02/01 15:52:28.614000000
# ...                ...           ...                            ...
# 2029978        2989059    2019006497                            NaN
# 2029979        2989060    2014068130                            NaN
# 2029993        2989074    2012008547                            NaN
# 2029994        2989075    2015030399                            NaN
# 2029995        2989076    2019014718                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 17       2010/01/04 09:48:05.604000000  2010/02/04 18:23:49.946000000
# ...

# %%
linhas_NaN_menos_Renovacao = linhas_NaN_menos_Renovacao[linhas_NaN_menos_Renovacao.drop(columns=['localizacao']).isna().any(axis=1)]
linhas_NaN_menos_Renovacao
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 17              709701       L163841  2010/01/19 19:02:53.450000000
# 98              709782       L165850                            NaN
# 109             709793       L178388  2010/01/19 16:31:44.491000000
# 118             709802    2009032201  2010/01/19 16:13:22.082000000
# 119             709803       L188583  2010/02/01 15:52:28.614000000
# ...                ...           ...                            ...
# 2029978        2989059    2019006497                            NaN
# 2029979        2989060    2014068130                            NaN
# 2029993        2989074    2012008547                            NaN
# 2029994        2989075    2015030399                            NaN
# 2029995        2989076    2019014718                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 17       2010/01/04 09:48:05.604000000  2010/02/04 18:23:49.946000000
# ...

# %% [markdown]
# # Day 2

# %% [markdown]
# ## Limpeza de dados

# %% [markdown]
# ### Removendo coluna registro_sistema

# %%
df_dados = df_dados.drop(columns=['registro_sistema'])

# %%
df_dados.columns
# Out:
# Index(['id_emprestimo', 'codigo_barras', 'data_renovacao', 'data_emprestimo',
#        'data_devolucao', 'matricula_ou_siape', 'tipo_vinculo_usuario',
#        'id_exemplar', 'colecao', 'biblioteca', 'status_material',
#        'localizacao'],
#       dtype='object')

# %%
df_dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2030010 entries, 0 to 2030009
# Data columns (total 12 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id_emprestimo         int64
#  1   codigo_barras         object
#  2   data_renovacao        object
#  3   data_emprestimo       object
#  4   data_devolucao        object
#  5   matricula_ou_siape    float64
#  6   tipo_vinculo_usuario  object
#  7   id_exemplar           float64
#  8   colecao               object
#  9   biblioteca            object
#  10  status_material       object
#  11  localizacao           float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 185.9+ MB

# %% [markdown]
# ### Mudando tipo de dados da coluna matricula_ou_siape para string

# %%
df_dados['matricula_ou_siape'] = df_dados['matricula_ou_siape'].astype(str)

# %% [markdown]
# ### Adicionando coluna CDU - Classificação Decimal Universal

# %%
df_dados['localizacao'].dtype
# Out:
# dtype('float64')

# %%
def CDU(localizacao):
    if localizacao < 100:
      return 'Generalidades. Ciência e conhecimento'
    elif localizacao < 200:
        return 'Filosofia e psicologia'
    elif localizacao < 300:
        return 'Religião'
    elif localizacao < 400:
        return 'Ciências sociais'
    elif localizacao < 500:
        return 'Classe vaga'
    elif localizacao < 600:
        return 'Matemática e ciências naturais'
    elif localizacao < 700:
        return 'Ciências aplicadas'
    elif localizacao < 800:
        return 'Belas artes'
    elif localizacao < 900:
        return 'Linguagem.Língua.Linguística'
    elif localizacao < 1000:
        return 'Geografia.História.Ciências sociais aplicadas'
    else:
      return 'Fora do padrão'

# %%
df_dados['CDU']=df_dados['localizacao'].apply(CDU)

# %%
df_dados.columns
# Out:
# Index(['id_emprestimo', 'codigo_barras', 'data_renovacao', 'data_emprestimo',
#        'data_devolucao', 'matricula_ou_siape', 'tipo_vinculo_usuario',
#        'id_exemplar', 'colecao', 'biblioteca', 'status_material',
#        'localizacao', 'CDU'],
#       dtype='object')

# %%
df_dados.head(5)
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         709685       L167050                            NaN
# 2         709686    2006017618  2010/01/26 08:07:01.738000000
# 3         709687       L184117  2010/01/18 11:07:46.470000000
# 4         709688    2007027500  2010/01/19 15:59:26.464000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 3  2010/01/04 08:24:21.284000000  2010/02/03 08:58:45.692000000
# 4  2010/01/04 08:27:33.569000000  2010/02/03 13:06:30.662000000
#
#   matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0       2008023265.0      ALUNO DE GRADUAÇÃO      13259.0  Acervo Circulante
# ...
